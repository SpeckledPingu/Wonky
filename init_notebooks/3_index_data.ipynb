# %%
import lancedb
import pandas as pd
import numpy as np
import json
from pathlib import Path
from tqdm.notebook import tqdm
from copy import deepcopy
import gzip
import re

# %%
base_folder = Path('../wonky_data')
index_folder = base_folder.joinpath('indexes')
source_folder = base_folder.joinpath('index_data/sections')
# source_folder = base_folder.joinpath('parsed_reports/sections')

# %%
db = lancedb.connect(index_folder)

# %%
source_files = list(source_folder.glob('*.json.gz'))

# %%
len(source_files)
# Out:
# 109

# %%
with gzip.open(source_files[0],'rt') as f:
    _data = json.load(f)
for record in _data:
    record['section_id'] = f"""{record['id']}_{record['section_start']}_{record['section_end']}"""

# %%
starter_data = pd.DataFrame(_data)

# %%
string_cols = ['id',
 'type',
 'typeId',
 'number',
 'topics',
 'date',
 'title',
 'summary',
 'doc_id',
 'filename',
 'source_file',
 'text',
 'sections']

# %%
starter_data
# Out:
#           id        type   typeId  number  active  \
# 0     R42373  CRS Report  REPORTS  R42373    True
# 1     R42373  CRS Report  REPORTS  R42373    True
# 2     R42373  CRS Report  REPORTS  R42373    True
# 3     R42373  CRS Report  REPORTS  R42373    True
# 4     R42373  CRS Report  REPORTS  R42373    True
# ...      ...         ...      ...     ...     ...
# 1664  R43778  CRS Report  REPORTS  R43778    True
# 1665  R43778  CRS Report  REPORTS  R43778    True
# 1666  R43778  CRS Report  REPORTS  R43778    True
# 1667  R43778  CRS Report  REPORTS  R43778    True
# 1668  R43778  CRS Report  REPORTS  R43778    True
#
#                                topics        date  \
# 0     [American Law, Foreign Affairs]  2012-02-24
# 1     [American Law, Foreign Affairs]  2012-02-24
# 2     [American Law, Foreign Affairs]  2012-02-24
# 3     [American Law, Foreign Affairs]  2012-02-24
# 4     [American Law, Foreign Affairs]  2012-02-24
# ...                               ...         ...
# 1664                               []  2014-11-07
# 1665                               []  2014-11-07
# 1666                               []  2014-11-07
# 1667                               []  2014-11-07
# 1668                               []  2014-11-07
#
#                                                   title  \
# 0     Issues in International Trade Law: Restricting...
# 1     Issues in International Trade Law: Restricting...
# 2     Issues in International Trade Law: Restricting...
# 3     Issues in International Trade Law: Restricting...
# 4     Issues in International Trade Law: Restricting...
# ...                                                 ...
# 1664      Medicaid Prescription Drug Pricing and Policy
# 1665      Medicaid Prescription Drug Pricing and Policy
# 1666      Medicaid Prescription Drug Pricing and Policy
# 1667      Medicaid Prescription Drug Pricing and Policy
# 1668      Medicaid Prescription Drug Pricing and Policy
#
#                                                 summary  doc_id  \
# 0     Electronic waste (e-waste) is a term that loos...  414169
# 1     Electronic waste (e-waste) is a term that loos...  414169
# 2     Electronic waste (e-waste) is a term that loos...  414169
# 3     Electronic waste (e-waste) is a term that loos...  414169
# 4     Electronic waste (e-waste) is a term that loos...  414169
# ...                                                 ...     ...
# 1664  Medicaid is a federal-state entitlement progra...  441591
# 1665  Medicaid is a federal-state entitlement progra...  441591
# 1666  Medicaid is a federal-state entitlement progra...  441591
# 1667  Medicaid is a federal-state entitlement progra...  441591
# 1668  Medicaid is a federal-state entitlement progra...  441591
#
#                                                filename  source_file  \
# 0     20120224_R42373_e0af9b8fc8c1464e8e9c4d8fa288ff...  R42373.json
# 1     20120224_R42373_e0af9b8fc8c1464e8e9c4d8fa288ff...  R42373.json
# 2     20120224_R42373_e0af9b8fc8c1464e8e9c4d8fa288ff...  R42373.json
# 3     20120224_R42373_e0af9b8fc8c1464e8e9c4d8fa288ff...  R42373.json
# 4     20120224_R42373_e0af9b8fc8c1464e8e9c4d8fa288ff...  R42373.json
# ...                                                 ...          ...
# 1664  20141107_R43778_411bfd4ca40cda0ae72915dd2ea401...  R43778.json
# 1665  20141107_R43778_411bfd4ca40cda0ae72915dd2ea401...  R43778.json
# 1666  20141107_R43778_411bfd4ca40cda0ae72915dd2ea401...  R43778.json
# 1667  20141107_R43778_411bfd4ca40cda0ae72915dd2ea401...  R43778.json
# 1668  20141107_R43778_411bfd4ca40cda0ae72915dd2ea401...  R43778.json
#
#                                                    text  \
# 0     # Issues in International Trade Law: Restricti...
# 1     ## International Agreements on Hazardous Waste...
# 2     ## Imposing a Ban on E-Waste Exports\n As disc...
# 3     ## Imposing a Licensing System on E-Waste Expo...
# 4     ### Article I\n Article I, also known as the g...
# ...                                                 ...
# 1664  ### Patient Protection and Affordable Care Act...
# 1665  ## Selected Medicaid Prescription Drug Issues\...
# 1666  ## Medicaid Rebates for Sovaldi\n Gilead parti...
# 1667  ### ACA Implementation: Pending Final Rule\n C...
# 1668  ## Conclusion\n In general, FFS rebates have b...
#
#                                                sections   section_ids  \
# 0     {'1': '# Issues in International Trade Law: Re...  [1, 2, 3, 4]
# 1     {'5': '## International Agreements on Hazardou...     [5, 6, 7]
# 2     {'8': '## Imposing a Ban on E-Waste Exports
#  A...           [8]
# 3     {'9': '## Imposing a Licensing System on E-Was...       [9, 10]
# 4     {'11': '### Article I
#  Article I, also known a...          [11]
# ...                                                 ...           ...
# 1664  {'45': '### Patient Protection and Affordable ...      [45, 46]
# 1665  {'47': '## Selected Medicaid Prescription Drug...      [47, 48]
# 1666  {'49': '## Medicaid Rebates for Sovaldi
#  Gilea...      [49, 50]
# 1667  {'51': '### ACA Implementation: Pending Final ...          [51]
# 1668  {'52': '## Conclusion
#  In general, FFS rebates...      [52, 53]
#
#       section_start  section_end  \
# 0                 1            4
# 1                 5            7
# 2                 8            8
# 3                 9           10
# 4                11           11
# ...             ...          ...
# 1664             45           46
# 1665             47           48
# 1666             49           50
# 1667             51           51
# 1668             52           53
#
#                                                  vector    section_id
# 0     [0.18518035113811493, 1.7670409679412842, -2.6...    R42373_1_4
# 1     [0.474021315574646, 1.617024302482605, -3.0516...    R42373_5_7
# 2     [0.5606708526611328, 2.607553005218506, -3.253...    R42373_8_8
# 3     [0.4774671792984009, 1.927130937576294, -2.882...   R42373_9_10
# 4     [0.5588755011558533, 1.3099936246871948, -3.00...  R42373_11_11
# ...                                                 ...           ...
# 1664  [0.9020079970359802, 0.9113937020301819, -2.81...  R43778_45_46
# 1665  [0.4073198437690735, 1.676227331161499, -2.708...  R43778_47_48
# 1666  [0.26424339413642883, 1.8337219953536987, -2.9...  R43778_49_50
# 1667  [0.6830442547798157, 1.0622128248214722, -3.19...  R43778_51_51
# 1668  [0.4500819444656372, 1.4310472011566162, -2.83...  R43778_52_53
#
# [1669 rows x 19 columns]

# %%
for _col in string_cols:
    starter_data[_col] = starter_data[_col].astype(str)

# %%
total_records = 0

# %%
tbl = db.create_table("sections_fts", data=starter_data, mode='overwrite')

# %%
total_records += starter_data.shape[0]

# %%
for file in tqdm(source_files[1:]):
    with gzip.open(file,'rt') as f:
        _data = json.load(f)
    for record in _data:
        record['section_id'] = f"""{record['id']}_{record['section_start']}_{record['section_end']}"""
    _data = pd.DataFrame(_data)
    for _col in string_cols:
        _data[_col] = _data[_col].astype(str)

    tbl.add(_data)
    total_records += _data.shape[0]
# Out:
#   0%|          | 0/108 [00:00<?, ?it/s]

# %%
total_records
# Out:
# 180709

# %%
tbl.create_index(metric="cosine")

# %%
tbl.create_fts_index(["text",'title','summary'], use_tantivy=True, replace=True)

# %%
from sentence_transformers import SentenceTransformer
encoder = SentenceTransformer('nomic-ai/nomic-embed-text-v1.5', device='mps',trust_remote_code=True)
# Out:
# !!!!!!!!!!!!megablocks not available, using torch.matmul instead
# <All keys matched successfully>

# %%
query = """USAID's headquarters in South Africa supports a "one-stop-shop" approach allowing access to the largest PAWG players: MCC, OPIC, Ex-Im, and USTDA, and the Commerce Department and its U.S. Foreign Commercial Service.  USAID has deployed more than 25 advisors across Africa.  A major technical assistance component of USAID's Power Africa work is the Power Africa Transactions and Reforms Program (PATRP), a three- to five-year, $64 million contract implemented by Tetra Tech and awarded in 2014."""
fts_query = ' '.join(re.findall(r'(\w+)', query))
query_vector = encoder.encode(query)

# %%
print(tbl.search(fts_query).limit(10).to_pandas().iloc[-2]['text'])
# Out:
# # Powering Africa: Challenges of and U.S. Aid for Electrification in Africa
#
#  September 14, 2015 (R43593)   [Jump to Main Text of Report](#Content) (R43593(1))
# ## Introduction
#  Sub-Saharan Africa is the most electricity-poor region globally, which has had profound impacts on economic growth and development prospects. In recent years, U.S. policymakers have sought to help increase access to electricity in sub-Saharan Africa in order to spur economic growth, reduce poverty, and for socio-economic development generally in the region; and to expand U.S. and other international trade with and investment in Africa.  Efforts to achieve these goals have taken the form of Power Africa, a major, multi-agency Obama Administration initiative to increase African access to electricity (also termed "power" in this report); and two congressional bills (one in the House and one in the Senate; see below).  The latter seek to establish as a U.S. policy priority a benchmarked, multi-year, market-driven and strategy-based program of power capacity-building aid and development partnership.  It would be broadly analogous to that pursued under Power Africa, but extend beyond the five-year duration of Power Africa and differing in scope.  They also set out mechanisms to support congressional oversight of all such activities, among other ends. (R43593(2))
# ## Recent Key Developments (R43593(3))
# ### Congressional Initiatives
#  Two bills to increase access to power in sub-Saharan Africa ("Africa" in this report, unless otherwise stated) have been introduced in the 114 \[th\] Congress.  In June 2015, the Chairman of the House Foreign Affairs Committee (HFAC), Representative Edward Royce, introduced [H.R. 2847](http://www.congress.gov/cgi-lis/bdquery/z?d114:H.R.2847:), the Electrify Africa Act of 2015.  [1] It seeks, among other ends, to make U.S. policy efforts, in partnership with sub-Saharan African countries and other partners, "to promote first time access to electricity and power services for at least 50 million people in sub-Saharan Africa by 2020, encourage installation of at least 20,000 additional megawatts (MW) of electricity, encourage necessary in-country reforms," and promote an energy development strategy that uses a wide range of fossil fuel and renewable energy sources.  On August 4, 2015, Senator Bob Corker, the Chairman of the Senate Foreign Relations Committee, introduced [S. 1933](http://www.congress.gov/cgi-lis/bdquery/z?d114:S.1933:), the Electrify Africa Act of 2015.  [2] The bill seeks "to establish a comprehensive United States Government policy to encourage the efforts of countries in sub-Saharan Africa to develop an appropriate mix of power solutions, including renewable energy, for more broadly distributed electricity access in order to support poverty reduction, promote development goals, and drive economic growth," among other ends.
#  The two bills are broadly similar in their approaches.  The main numerical policy targets of the two bills are nearly identical, and the broad approaches they lay out to achieve the ends they set out, which include an Executive Branch multi-year strategy, reporting to Congress on strategy implementation and progress, and U.S. leveraging of international support for this purpose are very similar, albeit not identical in their specifics.  Title II of both Acts would extend the issuing authority of the U.S. Overseas Private Investment Corporation (OPIC) to 2018 and set out a number of provisions to foster OPIC-administered power sector investment assistance in Africa.  There is substantial similarity between several of the two titles' Africa-related provisions, although they also substantively differ in important ways. Both titles also contain additional general OPIC provisions that are not necessarily related to Africa, of which some are roughly identical, but in other cases dissimilar.
#  The introduction of the two bills followed passage by the House during the 113 \[th\] Congress of [H.R. 2548](http://www.congress.gov/cgi-lis/bdquery/z?d113:H.R.2548:) (Royce), the Electrify Africa Act of 2014, and the introduction and reporting out of committee in the Senate, also during the 113 \[th\] Congress, of [S. 2508](http://www.congress.gov/cgi-lis/bdquery/z?d113:S.2508:) (Menendez), the Energize Africa Act of 2014. (R43593(4))

# %%
results = tbl.search(fts_query).limit(10).to_pandas()

# %%
results
# Out:
#         id        type   typeId   number  active  \
# 0   R43593  CRS Report  REPORTS   R43593    True
# 1   R43593  CRS Report  REPORTS   R43593    True
# 2   R43593  CRS Report  REPORTS   R43593    True
# 3   R43593  CRS Report  REPORTS   R43593    True
# 4   R43593  CRS Report  REPORTS   R43593    True
# 5   R43593  CRS Report  REPORTS   R43593    True
# 6   R43593  CRS Report  REPORTS   R43593    True
# 7   R43593  CRS Report  REPORTS   R43593    True
# 8   R43593  CRS Report  REPORTS   R43593    True
# 9  IB95052  CRS Report   REPORT  IB95052   False
#
#                                               topics        date  \
# 0  ['African Affairs', 'Economic Policy', 'Energy...  2015-09-14
# 1  ['African Affairs', 'Economic Policy', 'Energy...  2015-09-14
# 2  ['African Affairs', 'Economic Policy', 'Energy...  2015-09-14
# 3  ['African Affairs', 'Economic Policy', 'Energy...  2015-09-14
# 4  ['African Affairs', 'Economic Policy', 'Energy...  2015-09-14
# 5  ['African Affairs', 'Economic Policy', 'Energy...  2015-09-14
# 6  ['African Affairs', 'Economic Policy', 'Energy...  2015-09-14
# 7  ['African Affairs', 'Economic Policy', 'Energy...  2015-09-14
# 8  ['African Affairs', 'Economic Policy', 'Energy...  2015-09-14
# 9  ['Foreign Affairs', 'Intelligence and National...  2006-06-19
#
#                                                title  \
# 0  Powering Africa: Challenges of and U.S. Aid fo...
# 1  Powering Africa: Challenges of and U.S. Aid fo...
# 2  Powering Africa: Challenges of and U.S. Aid fo...
# 3  Powering Africa: Challenges of and U.S. Aid fo...
# 4  Powering Africa: Challenges of and U.S. Aid fo...
# 5  Powering Africa: Challenges of and U.S. Aid fo...
# 6  Powering Africa: Challenges of and U.S. Aid fo...
# 7  Powering Africa: Challenges of and U.S. Aid fo...
# 8  Powering Africa: Challenges of and U.S. Aid fo...
# 9             Africa: U.S. Foreign Assistance Issues
#
#                                              summary             doc_id  \
# 0  The largest infrastructure deficit in sub-Saha...             445388
# 1  The largest infrastructure deficit in sub-Saha...             445388
# 2  The largest infrastructure deficit in sub-Saha...             445388
# 3  The largest infrastructure deficit in sub-Saha...             445388
# 4  The largest infrastructure deficit in sub-Saha...             445388
# 5  The largest infrastructure deficit in sub-Saha...             445388
# 6  The largest infrastructure deficit in sub-Saha...             445388
# 7  The largest infrastructure deficit in sub-Saha...             445388
# 8  The largest infrastructure deficit in sub-Saha...             445388
# 9  Under the Administration's FY2006 foreign assi...  IB95052_2006Jun19
#
#                                             filename   source_file  \
# 0  20150914_R43593_f78bd8014e5835c314f0e1a3d83d32...   R43593.json
# 1  20150914_R43593_f78bd8014e5835c314f0e1a3d83d32...   R43593.json
# 2  20150914_R43593_f78bd8014e5835c314f0e1a3d83d32...   R43593.json
# 3  20150914_R43593_f78bd8014e5835c314f0e1a3d83d32...   R43593.json
# 4  20150914_R43593_f78bd8014e5835c314f0e1a3d83d32...   R43593.json
# 5  20150914_R43593_f78bd8014e5835c314f0e1a3d83d32...   R43593.json
# 6  20150914_R43593_f78bd8014e5835c314f0e1a3d83d32...   R43593.json
# 7  20150914_R43593_f78bd8014e5835c314f0e1a3d83d32...   R43593.json
# 8  20150914_R43593_f78bd8014e5835c314f0e1a3d83d32...   R43593.json
# 9  20060619_IB95052_44d064233dcac904568cea0844e16...  IB95052.json
#
#                                                 text  \
# 0  ## Agency Roles: USAID\n Power Africa is led b...
# 1  ## USTDA and USADF\n Under Power Africa, OPIC ...
# 2  ## Other Agencies and Power Africa Commitments...
# 3  ## Possible Issues and Questions for Congress\...
# 4  ### Power Africa: Key Achievements and Critiqu...
# 5  ### Goal and Focus\n The initiative is designe...
# 6  ## Outlook\n Now into its second year of imple...
# 7  ## Commerce and Energy Departments\n The Comme...
# 8  # Powering Africa: Challenges of and U.S. Aid ...
# 9  IB95052 06-19-06 The United States contributes...
#
#                                             sections   section_ids  \
# 0  {'26': '## Agency Roles: USAID\n Power Africa ...      [26, 27]
# 1  {'30': '## USTDA and USADF\n Under Power Afric...      [30, 31]
# 2  {'28': "## Other Agencies and Power Africa Com...      [28, 29]
# 3  {'34': '## Possible Issues and Questions for C...          [34]
# 4  {'5': '### Power Africa: Key Achievements and ...        [5, 6]
# 5  {'23': '### Goal and Focus\n The initiative is...  [23, 24, 25]
# 6  {'35': '## Outlook\n Now into its second year ...      [35, 36]
# 7  {'32': '## Commerce and Energy Departments\n T...      [32, 33]
# 8  {'1': '# Powering Africa: Challenges of and U....  [1, 2, 3, 4]
# 9  {'10': 'IB95052 06-19-06 The United States con...      [10, 11]
#
#    section_start  section_end  \
# 0             26           27
# 1             30           31
# 2             28           29
# 3             34           34
# 4              5            6
# 5             23           25
# 6             35           36
# 7             32           33
# 8              1            4
# 9             10           11
#
#                                               vector     section_id  \
# 0  [0.05080948, 1.144739, -3.275504, -0.4763342, ...   R43593_26_27
# 1  [0.5088026, 1.6286339, -3.574566, -0.3596658, ...   R43593_30_31
# 2  [0.34541905, 1.4823565, -3.8423011, -0.1534712...   R43593_28_29
# 3  [0.7185223, 1.922172, -2.5162842, -0.38139454,...   R43593_34_34
# 4  [0.5450391, 1.7149588, -3.3914585, -0.63610107...     R43593_5_6
# 5  [0.49734694, 1.0396512, -3.1792257, -0.3109190...   R43593_23_25
# 6  [0.5349806, 0.9393154, -2.8325799, -0.28838456...   R43593_35_36
# 7  [-0.18631841, 0.8763114, -3.9369643, -0.228735...   R43593_32_33
# 8  [0.48626584, 1.4472132, -3.7264488, -0.8857924...     R43593_1_4
# 9  [0.9512743, 0.7145364, -2.9581912, -0.36053047...  IB95052_10_11
#
#        _score
# 0  408.537201
# 1  302.317017
# 2  296.195251
# 3  263.290009
# 4  262.873962
# 5  261.087250
# 6  244.265686
# 7  243.185440
# 8  231.176651
# 9  226.688339

# %%
vec_results = tbl.search(query_vector).limit(10).to_pandas()

# %%
vec_results
# Out:
#         id          type   typeId   number  active  \
# 0   R43593    CRS Report  REPORTS   R43593    True
# 1   R43593    CRS Report  REPORTS   R43593    True
# 2   R43593    CRS Report  REPORTS   R43593    True
# 3  IB95052    CRS Report   REPORT  IB95052   False
# 4  IF11384  CRS In Focus       IF  IF11384    True
# 5  RL34003    CRS Report  REPORTS  RL34003   False
# 6   R41880    CRS Report  REPORTS   R41880    True
# 7  IF11384  CRS In Focus       IF  IF11384    True
# 8   R45687    CRS Report        R   R45687    True
# 9   R44117    CRS Report  REPORTS   R44117    True
#
#                                               topics        date  \
# 0  ['African Affairs', 'Economic Policy', 'Energy...  2015-09-14
# 1  ['African Affairs', 'Economic Policy', 'Energy...  2015-09-14
# 2  ['African Affairs', 'Economic Policy', 'Energy...  2015-09-14
# 3  ['Foreign Affairs', 'Intelligence and National...  2006-06-19
# 4             ['African Affairs', 'Foreign Affairs']  2020-11-17
# 5  ['African Affairs', 'Foreign Affairs', 'Intell...  2011-07-22
# 6                                ['Foreign Affairs']  2013-10-28
# 7             ['African Affairs', 'Foreign Affairs']  2020-11-17
# 8  ['African Affairs', 'Foreign Affairs', 'Nation...  2020-09-17
# 9  ['Appropriations', 'Economic Policy', 'Foreign...  2015-07-21
#
#                                                title  \
# 0  Powering Africa: Challenges of and U.S. Aid fo...
# 1  Powering Africa: Challenges of and U.S. Aid fo...
# 2  Powering Africa: Challenges of and U.S. Aid fo...
# 3             Africa: U.S. Foreign Assistance Issues
# 4  The Trump Administration’s Prosper Africa Init...
# 5  Africa Command: U.S. Strategic Interests and t...
# 6  Foreign Assistance: Public-Private Partnership...
# 7  The Trump Administration’s Prosper Africa Init...
# 8  South Africa: Current Issues, Economy, and U.S...
# 9  U.S. Agency for International Development (USA...
#
#                                              summary                doc_id  \
# 0  The largest infrastructure deficit in sub-Saha...                445388
# 1  The largest infrastructure deficit in sub-Saha...                445388
# 2  The largest infrastructure deficit in sub-Saha...                445388
# 3  Under the Administration's FY2006 foreign assi...     IB95052_2006Jun19
# 4                                               None  IF11384_6_2020-11-17
# 5  In recent years, analysts and U.S. policymaker...                389551
# 6  The flow of private sector resources to develo...                425223
# 7                                               None  IF11384_6_2020-11-17
# 8                                               None   R45687_9_2020-09-17
# 9  This report provides background information on...                443235
#
#                                             filename   source_file  \
# 0  20150914_R43593_f78bd8014e5835c314f0e1a3d83d32...   R43593.json
# 1  20150914_R43593_f78bd8014e5835c314f0e1a3d83d32...   R43593.json
# 2  20150914_R43593_f78bd8014e5835c314f0e1a3d83d32...   R43593.json
# 3  20060619_IB95052_44d064233dcac904568cea0844e16...  IB95052.json
# 4  2020-11-17_IF11384_6ecbb285e4a5fe0205123846047...  IF11384.json
# 5  20110722_RL34003_fda3a9182a25d4ccae4fe39536ac1...  RL34003.json
# 6  20131028_R41880_ea28073f5445e71704dfb18376c7cc...   R41880.json
# 7  2020-11-17_IF11384_6ecbb285e4a5fe0205123846047...  IF11384.json
# 8  2020-09-17_R45687_9ac66be2db5a89528302e6194976...   R45687.json
# 9  20150721_R44117_8021de4e0ae1c1185f341b8a174b72...   R44117.json
#
#                                                 text  \
# 0  ## Agency Roles: USAID\n Power Africa is led b...
# 1  ## Other Agencies and Power Africa Commitments...
# 2  ## USTDA and USADF\n Under Power Africa, OPIC ...
# 3  IB95052 06-19-06 Africa Enterprise Development...
# 4  Updated November 17, 2020 **The Trump Administ...
# 5  ## Headquarters Location\n There has been cons...
# 6  ### Other Bilateral Agencies\n While USAID and...
# 7  The Trump Administration’s Prosper Africa Init...
# 8  *South Africa: Current Issues, Economy, and U....
# 9  ### Mission and Headquarters Roles\n Organizat...
#
#                                             sections section_ids  \
# 0  {'26': '## Agency Roles: USAID\n Power Africa ...    [26, 27]
# 1  {'28': "## Other Agencies and Power Africa Com...    [28, 29]
# 2  {'30': '## USTDA and USADF\n Under Power Afric...    [30, 31]
# 3  {'15': 'IB95052 06-19-06 Africa Enterprise Dev...        [15]
# 4  {'1': 'Updated November 17, 2020 **The Trump A...         [1]
# 5  {'14': "## Headquarters Location\n There has b...        [14]
# 6  {'12': '### Other Bilateral Agencies\n While U...    [12, 13]
# 7  {'2': "The Trump Administration’s Prosper Afri...         [2]
# 8  {'9': '*South Africa: Current Issues, Economy,...         [9]
# 9  {'16': '### Mission and Headquarters Roles\n O...        [16]
#
#    section_start  section_end  \
# 0             26           27
# 1             28           29
# 2             30           31
# 3             15           15
# 4              1            1
# 5             14           14
# 6             12           13
# 7              2            2
# 8              9            9
# 9             16           16
#
#                                               vector     section_id  _distance
# 0  [0.05080948, 1.144739, -3.275504, -0.4763342, ...   R43593_26_27   0.372110
# 1  [0.34541905, 1.4823565, -3.8423011, -0.1534712...   R43593_28_29   0.389696
# 2  [0.5088026, 1.6286339, -3.574566, -0.3596658, ...   R43593_30_31   0.418164
# 3  [-0.00518867, 1.3195407, -3.6752663, -0.674701...  IB95052_15_15   0.418188
# 4  [0.21241844, 1.6974026, -3.0930176, -0.0020947...    IF11384_1_1   0.431043
# 5  [0.6275664, 0.72023827, -3.7677124, -0.6870053...  RL34003_14_14   0.432925
# 6  [0.45230317, 1.6280302, -3.2728295, -0.3164047...   R41880_12_13   0.436630
# 7  [0.32424703, 1.8523045, -2.8766463, 0.07541474...    IF11384_2_2   0.437528
# 8  [0.2895086, 0.2675329, -3.1297789, -0.29616845...     R45687_9_9   0.440551
# 9  [0.015327629, 0.7716815, -3.2985578, -0.158780...   R44117_16_16   0.442825
